# %%
#inventory
[all]
ahost ansible_connection=local

# %%
#task
shell: cat /etc/os-release 
register: output
# Out:
# {'counter': 32,
#  'created': '2021-05-31T22:41:06.909873',
#  'end_line': 31,
#  'event': 'runner_on_start',
#  'event_data': {'host': 'localhost',
#                 'play': 'Hello World',
#                 'play_pattern': 'all',
#                 'play_uuid': 'c417fe17-f6e3-9b94-b245-000000000006',
#                 'playbook': 'playbook.yml',
#                 'playbook_uuid': '8c6548b1-9cea-47ce-b106-72ef599c0c99',
#                 'task': 'include_vars',
#                 'task_action': 'include_vars',
#                 'task_args': '',
#                 'task_path': '/tmp/ansible_kernel_playbookdooxhg15/project/next_task0.yml:8',
#                 'task_uuid': 'c417fe17-f6e3-9b94-b245-000000000028',
#                 'uuid': 'c713d4bd-a382-4f7c-8a74-7aa102bd9c5a'},
#  'parent_uuid': 'c417fe17-f6e3-9b94-b245-000000000028',
#  'pid': 17787,
#  'runner_ident': '2dc77bde-c57e-4697-8772-abca25d07711',
#  'start_line': 31,
#  'stdout': '',
# ...
